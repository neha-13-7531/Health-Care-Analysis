# %% [markdown]
# # 🏥 Health Care Data Analysis

# %% [markdown]
# # Objective
# **To analyze and visualize a healthcare dataset to uncover patterns in patient demographics, hospital stays, treatments, readmissions, and outcomes — with the goal of identifying actionable insights for improving hospital operations and patient care.**

# %% [markdown]
# # Important Libraries
#
# # **1.Pandas**
# - pandas is used for to Data Manipulation and Data loading.
# - use import pandas as pd to import the library.
#
# # **2.Numpy**
# - NumPy (Numerical Python) is a Python library used for fast mathematical operations, especially with numbers, arrays, and large datasets. It works closely with Pandas to perform efficient calculations.
# - use import numpy as np to import library.
#
# # **3.matplotlib**
# - Matplotlib is a Python library used to create basic visualizations like line charts, bar graphs, pie charts, and scatter plots. It helps you see patterns in your data.
# - use import matplotlib.pyplot as plt to import this library.
#
# # **4.seaborn**
# - seaborn is a Python library built on top of Matplotlib that makes it easier to create beautiful, informative, and advanced visualizations with less code. It works especially well with Pandas DataFrames.
# - use import seaborn as sns to import this library.
#
# # **5.Profile Report**
# - To create a profile report.
# - use from ydata_profiling import ProfileReport

# %%
import pandas as pd # to data manipulation and data loading
import numpy as np # for mathematical calulation
import matplotlib.pyplot as plt # to visulization
# %matplotlib inline
import seaborn as sns  # used for advanced visulization

import plotly.express as px

# %%
from ydata_profiling import ProfileReport # create profile report
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
# loading dataset using read_xlsx method
df=pd.read_excel("C:\\Users\\Abc\\Downloads\\Healthcare_Data_Analysis.xlsx")

# %%
df.head() # get first 5 rows
# Out:
#      Patient ID  Age Gender      Diagnosis Treatment       Outcome  \
# 0  Patient-4279   70  Other  Heart Disease     image      Deceased
# 1  Patient-1803   74  Other   Hypertension    expert      Deceased
# 2  Patient-4069   88   Male       Diabetes      news  Deteriorated
# 3  Patient-2372   15  Other            Flu     leave      Deceased
# 4  Patient-9117    8   Male       COVID-19     think  Deteriorated
#
#    Length of Stay Readmission
# 0               9         Yes
# 1              21         Yes
# 2               6         Yes
# 3              19         Yes
# 4               9         Yes

# %%
df.tail() # get last 5 rows
# Out:
#         Patient ID  Age  Gender     Diagnosis Treatment       Outcome  \
# 4995  Patient-7053    7   Other      COVID-19    around      Deceased
# 4996  Patient-6968   74  Female      Diabetes      wall  Deteriorated
# 4997  Patient-7625   33    Male      Diabetes     issue      Deceased
# 4998  Patient-4994   44  Female      Diabetes      move      Deceased
# 4999  Patient-7337   89  Female  Hypertension     bring      Deceased
#
#       Length of Stay Readmission
# 4995               9          No
# 4996              28         Yes
# 4997               5          No
# 4998              15         Yes
# 4999              17          No

# %%
df.info() # get information of all column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient ID      5000 non-null   object
#  1   Age             5000 non-null   int64
#  2   Gender          5000 non-null   object
#  3   Diagnosis       5000 non-null   object
#  4   Treatment       5000 non-null   object
#  5   Outcome         5000 non-null   object
#  6   Length of Stay  5000 non-null   int64
#  7   Readmission     5000 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 312.6+ KB

# %%
df.isnull().sum() # checking missing values
# Out:
# Patient ID        0
# Age               0
# Gender            0
# Diagnosis         0
# Treatment         0
# Outcome           0
# Length of Stay    0
# Readmission       0
# dtype: int64

# %% [markdown]
# - There is no missing values is present.

# %%
df.shape # it return rows and column
# Out:
# (5000, 8)

# %% [markdown]
# - There are 5000 rows and 8 column are present.

# %%
df.duplicated().sum() # to check duplicate values
# Out:
# 0

# %% [markdown]
# - There are no duplicates values in dataset.

# %%
df.drop(['Patient ID','Treatment'],axis=1,inplace=True) # remove patient_id and Treatment column (not needed)

# %%
df.describe(include='all') # get summary of both categorical as well as numerical column
# Out:
#                 Age Gender     Diagnosis    Outcome  Length of Stay  \
# count   5000.000000   5000          5000       5000     5000.000000
# unique          NaN      3             5          4             NaN
# top             NaN  Other  Hypertension  Recovered             NaN
# freq            NaN   1685          1035       1277             NaN
# mean      49.989000    NaN           NaN        NaN       15.313000
# std       29.015893    NaN           NaN        NaN        8.627254
# min        0.000000    NaN           NaN        NaN        1.000000
# 25%       25.000000    NaN           NaN        NaN        8.000000
# 50%       50.000000    NaN           NaN        NaN       15.000000
# 75%       75.000000    NaN           NaN        NaN       23.000000
# max      100.000000    NaN           NaN        NaN       30.000000
#
#        Readmission
# count         5000
# unique           2
# top            Yes
# freq          2504
# mean           NaN
# std            NaN
# ...

# %% [markdown]
# **1.Age**
# - **count**: There are 5000 records are present, no missing value is present.
# - **mean**: The average/ mean for this coulmn is 49.98 , mean around is 50 ,the average Patient age is are 50.
# - **std** : The standard deviation of age column is 29.01 which is less than mean.
# - **min** : There is no minimum age is 0.
# - **25% (Q1) : The 25% of this column 25 i.e 25 values are fall in 25%.
# - **50%** : The middle value of this age column is 50.
# - **75% (Q3) : The 75% value is 75 which is greater than Q1 and middle value.
#
# **2.Gender**
# - **count**: There are 5000 entries in gender column.
# - **unique** : The unique value in this column is 3 (Male,Female,other).
# - **top** : The top most gender is other*.
# - **freq** other gender are 1685 times are repeat.
#
# **3.Diagnosis**
# - **count** : There are 5000 records are present.
# - **unique**  : The unique in  this column is 5.
# - **top** : The top most Diagnosis is Hypertension.
# - **freq** : The Hypertension is repeated 1035 times.
#
# **4.Outcome**
# - **count** : The total count of coutcome is 5000.
# - **unique** : The unique values in this 4.
# - **top** :  Top outcome is recovered. i.e  most of the patient are recovered.
# - **freq**:  Total 1277 patient are recovered.
#
# **5.Length of Stay**
# - **count**: There are 5000 records are present, no missing value is present.
# - **mean**: The average/ mean for this coulmn is 15.31 , mean around is 15 ,the average Patient  stay in hospital in days are 15.
# - **std** : The standard deviation of age column is 8.62 which is less than mean.
# - **min** : The minimum days are patient in hospital is 1 day.
# - **25% (Q1) : The 25 % value is 8 that show the there below vaules are 25 % of the data fall.
# - **50%** : The middle value of this column is 15.
# - **75% (Q3) : The 75% value is 23 days which is greater than Q1 and middle value.
#
# **6.Readmission**
# - **count** : There is 5000 entries in this column.
# - **uniue** : There are 2 unique values in this column (yes,no).
# - **top** : Top most values is yes.
# - **freq** : yes are 2504 times are repeated.

# %%
df[df['Age'] ==0] # to check the values whose age is 0
# Out:
#       Age  Gender      Diagnosis       Outcome  Length of Stay Readmission
# 166     0  Female  Heart Disease  Deteriorated              13         Yes
# 286     0   Other            Flu  Deteriorated              29          No
# 363     0   Other       Diabetes      Improved              24         Yes
# 416     0    Male  Heart Disease     Recovered              24          No
# 506     0    Male  Heart Disease      Deceased              13         Yes
# 543     0  Female       COVID-19      Improved               8         Yes
# 558     0    Male       Diabetes      Improved              13         Yes
# 771     0    Male   Hypertension  Deteriorated               1          No
# 854     0    Male       COVID-19      Improved              25          No
# 1307    0  Female  Heart Disease      Improved               7         Yes
# 1367    0    Male  Heart Disease      Deceased               8          No
# ...

# %%
# In some cases age is 0  which is not correct so filling random age between 20 to 90

import random  # import random to generate random values in our 'Age' column
# randint() is used to generate random integer between two numbers
df['Age'] = df['Age'].apply(lambda x : random.randint(20, 90) if x == 0 else x)

# %%
df.shape
# Out:
# (5000, 6)

# %% [markdown]
# - After removimg 2 columns there are 5000 rows and 6 columns are present.

# %%
df.head()
# Out:
#    Age Gender      Diagnosis       Outcome  Length of Stay Readmission
# 0   70  Other  Heart Disease      Deceased               9         Yes
# 1   74  Other   Hypertension      Deceased              21         Yes
# 2   88   Male       Diabetes  Deteriorated               6         Yes
# 3   15  Other            Flu      Deceased              19         Yes
# 4    8   Male       COVID-19  Deteriorated               9         Yes

# %%
df[df['Age']==50] # check the records whose patient age is 50
# Out:
#       Age  Gender      Diagnosis       Outcome  Length of Stay Readmission
# 122    50   Other       COVID-19      Deceased               4         Yes
# 125    50    Male       Diabetes  Deteriorated              27         Yes
# 189    50    Male  Heart Disease  Deteriorated              15         Yes
# 267    50   Other  Heart Disease  Deteriorated              25          No
# 323    50    Male            Flu  Deteriorated               9          No
# 436    50  Female            Flu      Deceased              12         Yes
# 575    50  Female       Diabetes  Deteriorated               3         Yes
# 599    50  Female   Hypertension     Recovered              18         Yes
# 841    50   Other  Heart Disease     Recovered              18          No
# 868    50   Other       Diabetes      Deceased              19          No
# 892    50    Male   Hypertension     Recovered               2         Yes
# ...

# %%
df.nunique() # unique values
# Out:
# Age               100
# Gender              3
# Diagnosis           5
# Outcome             4
# Length of Stay     30
# Readmission         2
# dtype: int64

# %% [markdown]
# - There are 100 entries are unique in age column. it randomly get value.
# - 3 unique genders are present(female,male,other).
# - Diagnosis column have 5 unique values.
# - In outcome 4 unique values are there.
# - In length of stay have 30 unique values.
# - There are 2 unique readmission.(yes,no).

# %%
df[df['Length of Stay'] ==10] # This shows the record whose length of stay is 10
# Out:
#       Age  Gender     Diagnosis       Outcome  Length of Stay Readmission
# 5      87    Male      COVID-19      Deceased              10         Yes
# 26     92    Male      COVID-19      Deceased              10          No
# 74     30  Female           Flu  Deteriorated              10          No
# 123    18   Other           Flu     Recovered              10         Yes
# 141    42   Other      Diabetes      Deceased              10          No
# ...   ...     ...           ...           ...             ...         ...
# 4716   87  Female  Hypertension      Deceased              10         Yes
# 4719   73  Female  Hypertension      Improved              10         Yes
# 4743   98    Male           Flu      Deceased              10          No
# 4750   39    Male      COVID-19  Deteriorated              10         Yes
# 4758   88   Other      Diabetes  Deteriorated              10         Yes
#
# [164 rows x 6 columns]

# %%
df.sort_values(by="Length of Stay",ascending=False) # sort the actual price by ascending order
# Out:
#       Age  Gender     Diagnosis       Outcome  Length of Stay Readmission
# 1353   48   Other      COVID-19     Recovered              30         Yes
# 442    35    Male      COVID-19      Improved              30         Yes
# 3643   89   Other      COVID-19     Recovered              30         Yes
# 4785   36   Other      Diabetes  Deteriorated              30         Yes
# 4786   51    Male      COVID-19  Deteriorated              30          No
# ...   ...     ...           ...           ...             ...         ...
# 4806   73   Other           Flu      Deceased               1         Yes
# 1070   60   Other      Diabetes     Recovered               1         Yes
# 1554   90  Female  Hypertension      Improved               1         Yes
# 3688   58  Female      COVID-19      Deceased               1          No
# 4565   15  Female      Diabetes      Deceased               1          No
#
# [5000 rows x 6 columns]

# %%
# show the values whose Age is 50 and Diagnosis is Hypertension
df[(df['Age']== 60)  & (df['Diagnosis'] == 'Hypertension')]
# Out:
#       Age  Gender     Diagnosis       Outcome  Length of Stay Readmission
# 877    60  Female  Hypertension  Deteriorated               1          No
# 1428   60    Male  Hypertension      Improved              17          No
# 1475   60   Other  Hypertension     Recovered               4          No
# 1621   60    Male  Hypertension      Improved               9         Yes
# 3308   60    Male  Hypertension      Improved               1         Yes
# 3757   60    Male  Hypertension  Deteriorated              26          No
# 4080   60  Female  Hypertension      Deceased               9          No
# 4226   60  Female  Hypertension  Deteriorated               3         Yes
# 4307   60    Male  Hypertension      Deceased              22          No
# 4366   60    Male  Hypertension     Recovered              13          No
# 4645   60    Male  Hypertension     Recovered              15          No

# %%
df[df['Outcome'] =='Recovered']  # check the record whose outcome is recovred
# Out:
#       Age  Gender      Diagnosis    Outcome  Length of Stay Readmission
# 10     43   Other       Diabetes  Recovered              16         Yes
# 11     24  Female  Heart Disease  Recovered              30          No
# 12     29    Male  Heart Disease  Recovered               9          No
# 13     91   Other            Flu  Recovered              15         Yes
# 14     19    Male            Flu  Recovered              30          No
# ...   ...     ...            ...        ...             ...         ...
# 4979    5    Male       COVID-19  Recovered              27          No
# 4981   61   Other            Flu  Recovered              14         Yes
# 4983   36    Male            Flu  Recovered               3         Yes
# 4988   10   Other            Flu  Recovered              29          No
# 4989   67  Female       COVID-19  Recovered               9          No
#
# [1277 rows x 6 columns]

# %%
df['Diagnosis'].unique() # check unique value in Diagnosis column
# Out:
# array(['Heart Disease', 'Hypertension', 'Diabetes', 'Flu', 'COVID-19'],
#       dtype=object)

# %% [markdown]
# - There are **'Heart Disease'**, **'Hypertension'**, **'Diabetes'**, **'Flu'**, **'COVID-19'** this 5 unique values  are present in this column.

# %%
df['Outcome'].unique() # check unique value in Outcome column
# Out:
# array(['Deceased', 'Deteriorated', 'Improved', 'Recovered'], dtype=object)

# %% [markdown]
# - The outcome have **'Deceased'**, **'Deteriorated'**, **'Improved'**, **'Recovered'** this 4 unique values are present.

# %%
df['Readmission'].unique() # check unique values in readmission column
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# - There are 2 unique values are present in this column like **Yes** and **No** .

# %%
df.nunique().sum()
# Out:
# 144

# %% [markdown]
# - There are 144 unique values are present in dataset.

# %%
df['Diagnosis'].nunique() # count of Daignosis column
# Out:
# 5

# %%
df.columns # display column name
# Out:
# Index(['Age', 'Gender', 'Diagnosis', 'Outcome', 'Length of Stay',
#        'Readmission'],
#       dtype='object')

# %%
# check the duplicates in Diagnosis column
df['Diagnosis'].duplicated().sum()
# Out:
# 4995

# %% [markdown]
# - There are 4995 entries are duplicates in this column.

# %%
# check the duplicates in outcome column
df['Outcome'].duplicated().sum()
# Out:
# 4996

# %% [markdown]
# - In Outcome column 4996 values are duplicates.

# %%
profile=ProfileReport(df)   # create profile report
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.16.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-08-05 08:38:29.880396&quot;&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
df['Diagnosis'].value_counts() # total count of every Diagnosis
# Out:
# Diagnosis
# Hypertension     1035
# Diabetes         1020
# Heart Disease    1004
# Flu               996
# COVID-19          945
# Name: count, dtype: int64

# %% [markdown]
# - There are 1035 patients are suffering from Hypertension disease.
# - 1020 patients whos have Diabetes.
# - There are 1004 patient have Heart Disease.
# - 996 patients have FLU.
# - There are 945 patients have suffering from COVID-19.

# %%
df['Readmission'].value_counts() # total count of readmission
# Out:
# Readmission
# Yes    2504
# No     2496
# Name: count, dtype: int64

# %% [markdown]
# - There are **2504** patients  are readmitted after the discharge.
# - **2496** patients are not need to readmitted.

# %%
df['Outcome'].value_counts() # total count of every outcome
# Out:
# Outcome
# Recovered       1277
# Improved        1261
# Deteriorated    1248
# Deceased        1214
# Name: count, dtype: int64

# %% [markdown]
# - The number of patients who recovered is 1214.
# - A total of 1277 patients showed improvement in their condition.
# - The condition of 1261 patients deteriorated.
# - Unfortunately, 1248 patient are Deceased, i.e patients did not survive.

# %%
# calculate the average of Diagnosis by its legth of stay
df.groupby("Diagnosis")["Length of Stay"].mean()
# Out:
# Diagnosis
# COVID-19         15.428571
# Diabetes         15.965686
# Flu              15.414659
# Heart Disease    14.577689
# Hypertension     15.179710
# Name: Length of Stay, dtype: float64

# %% [markdown]
# - The average length of stay for patients with COVID-19 is approximately 15.43 days.
# - Patients diagnosed with Heart Disease have an average length of stay of around 14.57 days.
# - The patient whose diagnosis with Diabetes have an average length of stay of around 15.96 days.
# - The average length of stay for patients with FLU is approximately 15.41 days.
# - Patients diagnosed with Hypertension have an average length of stay of around 15.17 days.

# %%
df.index # it return the row index
# Out:
# RangeIndex(start=0, stop=5000, step=1)

# %% [markdown]
# - The index is start from 0 to 5000 with step 1.

# %% [markdown]
# # EDA (Explorotory Data Analysis)
# - **EDA is essential because it helps you understand your data before applying any models, visualizations, or business decisions.**
#
# # **Types of EDA**
#
# # **1.Univariate Analysis**
# - **Analyzing and comparing a single feature(column) within itself.**
#
# # **2.Bivariate Analysis**
# - **Analyzing and comparing a two features in order to find there relationship,underlying pattern and trends between them.**
#
# # **3.Multivariate Analysis**
# - **Analyzing and comparing more than two feature in order to find the relationship,trends,dependncies between them.**

# %%
df.to_csv("HealthCare.csv",index=False) # to saving dataframe to csv file index=False it contain only actual data without extra index column.

# %%
# univariate Analysis
# histplot for age distribution
plt.figure(figsize=(10,6))
ax=sns.histplot(df['Age'],bins=20,kde=True,color='purple')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Distribution")
plt.show()

# %% [markdown]
# - The highest counts are observed in the age ranges around 60-70 years and 70-80 years, with values slightly above 282 and 289.
# - The lowest counts are seen in the youngest age group (0-5 years) and the oldest age group (95-100 years), with values around 238 and 210, respectively.
# - From 0 graph is slightly increased after they are steady from 20 some peak are also find after 80 year is decreased.

# %%
# histplot for watch time minutes
plt.figure(figsize=(12,6))
sns.histplot(df['Length of Stay'],bins=20,kde=True,color='red')
plt.show()

# %% [markdown]
# 1. The graph shows a relatively consistent distribution of length of stay across different ranges, with most counts falling between 250 and 350.
# 2. The highest count is observed in the range of 2-3 days, with a count of approximately 320.
# 3. The lowest count is observed in the range of 8-9 days, with a count of around 220.
# 4. The graph also shows a slight decrease in count as the length of stay increases beyond 15 days.
# 5. The overall trend suggests that most patients have a relatively short length of stay, with the majority staying for less than 10 days.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# count for readmission
plt.figure(figsize=(10,4))
ax=sns.countplot(x=df['Readmission'],palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("ReadMission  Distribution")
plt.xlabel("Readmission")
plt.ylabel("Distribution")
plt.show()

# %% [markdown]
# - The Highest count is yes i.e 2504 that is most patients are readmitted after the discharge.
# - 2496 patients are not needed to readmitted to hospital again.

# %%
# count for gender
plt.figure(figsize=(10,6))
ax=sns.countplot(x=df['Gender'],palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Gender Distribution ")
plt.xlabel("gender ")
plt.ylabel("Distribution")
plt.show()

# %% [markdown]
# - The highest count of patients are Other with count 1685.
# - Then 1656 Male patients are their.
# - There are 1659 patients are Female.

# %%
plt.figure()
sns.boxplot(x=df['Age'],palette='coolwarm')
plt.title("Box plot for Age feature")
plt.show()

# %% [markdown]
# - There are no outlier are present in Age column.

# %%
# box plot for length of stay
plt.figure()
sns.boxplot(x=df['Length of Stay'],palette='coolwarm')
plt.title("Box plot for Length of Stay")
plt.show()

# %% [markdown]
# - In Length of Stay column their are no outlier is present.

# %%
# count plot for gender vs readmission
plt.figure(figsize=(8,4))
ax=sns.countplot(data=df,x='Gender',hue='Readmission',palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Gender vs Readmission")
plt.xlabel("Gender")
plt.ylabel("Readmission")
plt.show()

# %% [markdown]
# - In other gender there are 874 patients who have readmitted after the discharge and 811 patients are not need to readmitted, The count of yes is greater than No.
# - In Male patients the count of readmitted after the discharge is less than(817) the patient who not admitted again(839).
# - In Male patients the count of readmitted after the discharge is less than(813) the patient who not admitted again(846).

# %%
#  univariate for categorical column
def univariate_categorical(categorical_columns, df):
    for column in categorical_columns:
        plt.figure(figsize=(8,6))
        df[column].value_counts().head().plot(kind='bar')
        plt.title(f'Distribution of {column}')
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.show()
categorical_columns = ['Gender', 'Diagnosis', 'Outcome', 'Readmission']
univariate_categorical(categorical_columns, df)

# %% [markdown]
# **1.Distribution of Gender**
# - The highest gender count is **other** is above 1600.
# - The count for **female** and **male** gender category is roughly the same.
#
# **2.Distribution of Diagnosis**
# - The graph indicates that hypertension has the highest count, followed closely by diabetes and heart disease, which are roughly equal. Flu and COVID-19 have lower counts.
#
# **3.Distribution of Outcome**
# - The outcomes "Recovered," "Improved," "Deteriorated," and "Deceased" all have approximately equal counts, around 1200.
#
# **4.Distribution of Readmission**
# - The highest count is Readmitted patient.

# %%
# Bivariate Analysis for categorical column

cat_col=['Gender','Outcome','Diagnosis']
def bivariate_analysis(n):
    plt.figure(figsize=(14,10))
    for i,col in enumerate(n,1):
        plt.subplot(2,2,i)
        plt.title(f"count of {col}")
        sns.countplot(x=df[col],hue='Readmission',data=df)
    plt.show()
bivariate_analysis(cat_col)

# %% [markdown]
# **1.Count of Gender**
# - The "Other" gender category has a higher count of readmitted patients (around 850) compared to those not readmitted (around 800), indicating a slightly higher likelihood of readmission.
# - Males have a relatively balanced count between readmitted (around 800) and not readmitted (around 800) patients, suggesting that readmission rates are roughly equal for this gender.
# - Females have a lower count of readmitted patients (around 750) compared to those not readmitted (around 800), indicating a slightly lower likelihood of readmission.
#
# **2.Count of Outcome**
# - In the "Deceased" category, the count for "Yes" readmission is slightly higher than for "No" readmission.
# - The "Deteriorated" category has the highest count for both "Yes" and "No" readmission, suggesting that patients who deteriorate are more likely to be readmitted.
# - The identical counts for "Yes" and "No" readmission in the "Improved" and "Recovered" categories imply that readmission status may not be a significant factor in determining the outcome for patients who improve or recover.
#
# **3.Count of Diagnosis**
# - In Heart Diesease the count of readmitted patient is greater than non-admitted patient.
# - In Hypertension diagnosis count of non-admitted patient is greater than admitted patient.
# - In Diabetes count of non-admitted patient is greater than admitted patient.
# - In Flu column non-admitted patient is greater than admitted patient.
# - In COVID-19 readmitted patient is greater than non-admitted patient.

# %%
# correlation for discounted price,actual price,rating count,final price and rating
correlation=df[['Age','Length of Stay']].corr() 
print(correlation)
plt.figure(figsize=(6,4))
sns.heatmap(correlation,annot=True)
plt.title('Heatmap of correlation')
plt.show()
# Out:
#                      Age  Length of Stay
# Age             1.000000        0.014563
# Length of Stay  0.014563        1.000000

# %% [markdown]
# - In this correlation matrix every column is strongly correlated to itself ,i.e the coefficient of correlation is closly to 1.
# - The 'Age' and 'Length of Stay' this two columns are weekly correlated or no correlated i.e the coefficient of correlation is closly to 0.

# %%
# pie chart of value_counts() of outcome
outcome_counts = df['Outcome'].value_counts()
custom_colors = ['#008080', '#66ffff', '#00cccc','#009999']
plt.figure(figsize=(4, 4))
plt.pie(outcome_counts, labels = outcome_counts.index, autopct='%1.1f%%', colors = custom_colors, startangle = 90)
plt.title('Distribution of Outcome ')
plt.axis('equal')  
plt.show()

# %% [markdown]
# - **Recovered (25.5%)**: A significant proportion, 25.5%, of the patients in the dataset have fully recovered from their health conditions, indicating successful treatment and care.
# - **Deceased (24.3%)**: Unfortunately, 24.3% of the patients have succumbed to their health issues, highlighting the severity of certain conditions within the dataset.
# - **Deteriorated (25.0%)**: The health of 25.0% of the patients has deteriorated, suggesting that their conditions have worsened despite or due to the treatment they received.
# - **Improved (25.2%)**: A total of 25.2% of the patients have shown improvement in their health, indicating positive outcomes from the interventions or treatments they underwent.

# %%
# pie chart of value_counts() of outcome
outcome_counts = df['Diagnosis'].value_counts()
custom_colors = ['#008080', '#66ffff', '#00cccc','#009999']
plt.figure(figsize=(4, 4))
plt.pie(outcome_counts, labels = outcome_counts.index, autopct='%1.1f%%', colors = custom_colors, startangle = 90)
plt.title('Distribution of Diagnosis ')
plt.axis('equal')  
plt.show()

# %% [markdown]
# - Hypertension is the most common condition, total percent is 20.7% .
# - Diabetes is the second most prevalent condition, making up 20.4%.
# - Heart Disease is closely related, representing 20.1%.
# - Flu and COVID-19 are also significant, with 19.9% and 18.9%, respectively.

# %%
# pie chart of value_counts() of gender
gender_counts = df['Gender'].value_counts()
custom_colors = ['#FFB347', '#77DD77', '#AEC6CF']
plt.figure(figsize=(8, 6))
plt.pie(gender_counts, labels = gender_counts.index, autopct='%1.1f%%', colors = custom_colors, startangle = 90)
plt.title('Distribution of Gender ')
plt.axis('equal')  
plt.show()

# %% [markdown]
# - **Male (33.1%)**: The male category have 33.1% patient.
# - **Female (33.2%)**: The female category is slightly higher than the male category, making up about 33.2% of the dataset, showing a near-equal distribution between males and females.
# - **Other (33.7%)**: The "Other" category, which could include non-binary individuals or those who prefer not to specify their gender, makes up the largest portion of the dataset at 33.7%.

# %% [markdown]
# # Recommendation

# %% [markdown]
# **1. The histogram shows most patients have a short hospital stay (0–5 days), with fewer cases beyond 10 days.**
# - **recommendation** : Optimize resources for short-stay treatments and consider offering more outpatient care packages.
#
# **2. The count plot for readmission shows that readmissions are present but not dominant.This could suggest effective initial treatment but should still be monitored.**
# - **recommendation**  : Investigate causes of readmissions (e.g., specific departments or age groups) and develop follow-up care programs.
#
# **3. Top values in Diagnosis, Treatment, and Outcome are clearly dominated by a few categories.**
# - **recommendation** : Focus resources and awareness programs on the most common diagnoses and treatments.
#
# **4.The pie chart shows distribution of patient outcomes (e.g., Recovered, Improved, Deceased).Most patients fall into Recovered or Improved, with a small portion showing worse outcomes.**
# - **recommendation** : While majority outcomes are positive, analyze patterns in the negative outcomes.
